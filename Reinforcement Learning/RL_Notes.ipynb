# %% [markdown]
# ## Importing Dependent modules

# %%
# !pip install stable-baselines3[extra]
# Out:
# Requirement already satisfied: stable-baselines3[extra] in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (1.8.0)
# Requirement already satisfied: importlib-metadata~=4.13 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]) (4.13.0)
# Requirement already satisfied: numpy in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]) (1.25.0)
# Requirement already satisfied: torch>=1.11 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]) (2.0.1)
# Requirement already satisfied: matplotlib in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]) (3.5.1)
# Requirement already satisfied: cloudpickle in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]) (2.2.1)
# Requirement already satisfied: gym==0.21 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]) (0.21.0)
# Requirement already satisfied: pandas in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]) (1.4.1)
# Requirement already satisfied: psutil in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]) (5.9.0)
# Requirement already satisfied: autorom[accept-rom-license]~=0.6.0 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: opencv-python in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]) (4.7.0.72)
# Requirement already satisfied: tqdm in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]) (4.65.0)
# Requirement already satisfied: tensorboard>=2.9.1 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]) (2.13.0)
# Requirement already satisfied: ale-py==0.7.4 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]) (0.7.4)
# Requirement already satisfied: pillow in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]) (9.0.1)
# Requirement already satisfied: rich in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]) (13.4.2)
# Requirement already satisfied: importlib-resources in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from ale-py==0.7.4->stable-baselines3[extra]) (5.12.0)
# Requirement already satisfied: requests in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (2.28.0)
# Requirement already satisfied: click in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (8.1.3)
# Requirement already satisfied: AutoROM.accept-rom-license in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from importlib-metadata~=4.13->stable-baselines3[extra]) (3.15.0)
# Requirement already satisfied: wheel>=0.26 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.37.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.20.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.0.0)
# Requirement already satisfied: protobuf>=3.19.6 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (4.23.3)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.3.6)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.54.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.1)
# Requirement already satisfied: absl-py>=0.4 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (58.1.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.4.3)
# Requirement already satisfied: filelock in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.11->stable-baselines3[extra]) (3.6.0)
# Requirement already satisfied: jinja2 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.11->stable-baselines3[extra]) (3.1.1)
# Requirement already satisfied: sympy in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.11->stable-baselines3[extra]) (1.12)
# Requirement already satisfied: typing-extensions in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.11->stable-baselines3[extra]) (4.6.3)
# Requirement already satisfied: networkx in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.11->stable-baselines3[extra]) (3.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->stable-baselines3[extra]) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.31.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from pandas->stable-baselines3[extra]) (2022.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from rich->stable-baselines3[extra]) (2.15.1)
# Requirement already satisfied: colorama in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from tqdm->stable-baselines3[extra]) (0.4.4)
# Requirement already satisfied: six>=1.9.0 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.3.0)
# Requirement already satisfied: urllib3<2.0 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (1.26.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (5.3.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (2022.5.18.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (2.0.12)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from sympy->torch>=1.11->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (3.2.2)
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [raw]
# stable_baseline3 documentation : "https://stable-baselines3.readthedocs.io/en/master/"

# %%
import os #to pass paths and to save and log out

# %%
import gym #allow us to build environments and also work with pre existing environments

# %%
from stable_baselines3 import PPO    #an RL algorithm form baseline pakage

# %%
from stable_baselines3.common.vec_env import DummyVecEnv  #dummy vectorised environment to train different models at the same time

# %%
from stable_baselines3.common.evaluation import evaluate_policy     
#to test how model is performing to get avg reward after certain number of epsords

# %% [markdown]
# ## Load Environments

# %% [raw]
# gym documentation : "https://www.gymlibrary.dev/content/basic_usage/"

# %% [raw]
# cart pole environment documentation : "https://www.gymlibrary.dev/environments/classic_control/cart_pole/"

# %%
# !pip install pyglet==1.5.27
#pyglet is a cross-platform windowing and multimedia library for Python, intended for developing games and other visually rich applications
# Out:
# Requirement already satisfied: pyglet==1.5.27 in c:\users\hrith\appdata\local\programs\python\python310\lib\site-packages (1.5.27)
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
environment_name='CartPole-v0'

# %%
env=gym.make(environment_name)

# %%
#Trying to test the cartpole evn 5 itmes:

episodes = 5                                                        #loop in 5 times
for episode in range(1, episodes+1):
    state = env.reset()                                             #reset the evironment to initial conditins
    done = False                                                    #setting variables
    score = 0 
    
    while not done:
        env.render()                                                #view the graphical representation of environment 
        action = env.action_space.sample()                          #generate a random action space
        n_state, reward, done, info = env.step(action)              #passing action to environment 
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:19.0
# Episode:2 Score:33.0
# Episode:3 Score:10.0
# Episode:4 Score:31.0
# Episode:5 Score:24.0

# %% [raw]
# Basically what we are doing in the above code is that loading a environment ,
# initial states and using loop finding forwards states 5 times

# %%
env.reset()   #these are the observations we get for environment
# Out:
# array([-0.0490357 , -0.03807538, -0.02438258, -0.02018723], dtype=float32)

# %%
env.action_space.sample()      #there are two space in this example (0,1) anyone is selected at random
# Out:
# 0

# %%
env.observation_space.sample()        #gives observation space
# Out:
# array([ 2.4195108e+00,  3.6727641e+37,  4.2447452e-02, -1.5034697e+38],
#       dtype=float32)

# %% [markdown]
# ## Undernstand the algorithm

# %% [raw]
# https://github.com/openai/gym/blob/master/gym/envs/classic_control/cartpole.py

# %%
env.action_space
# Out:
# Discrete(2)

# %%
env.action_space.sample()      
#there are two space in this example (0,1) anyone is selected at random
#i.e box moving left or right
# Out:
# 1

# %%
env.observation_space
# Out:
# Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)

# %%
env.observation_space.sample()        
#gives observation space , e.e Cart Position,Cart Velocity,Pole Angle,Pole Angular Velocity
# Out:
# array([ 1.7382528e+00, -2.4266128e+38,  4.0516815e-01,  1.0352617e+38],
#       dtype=float32)

# %% [markdown]
# ## Train the RL model

# %%
#make directory first
log_path=os.path.join('Training','Logs')   #to save logs to monitor our training

# %%
log_path
# Out:
# 'Training\\Logs'

# %%
env=gym.make(environment_name)                                            #creating the environment
env=DummyVecEnv([lambda: env])                                            #wrapped our environment into dummy env
model = PPO('MlpPolicy',env,verbose=1,tensorboard_log=log_path)           #think of it as defining out agent
# verbose=1 to seve results
# MlpPolicy = the policy we r using
# Out:
# Using cpu device

# %% [raw]
# Error : Could not infer dtype of numpy.float32
# To solve this error: upgrade all existing pakages using
# pip install --upgrade gym stable_baselines3 numpy

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training\Logs\PPO_1
# -----------------------------
# | time/              |      |
# |    fps             | 793  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 571         |
# |    iterations           | 2           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008128976 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.00449    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.1        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 65.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 526         |
# |    iterations           | 3           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010394334 |
# |    clip_fraction        | 0.0722      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.662      |
# |    explained_variance   | 0.0701      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.3        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0196     |
# |    value_loss           | 40.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 503         |
# |    iterations           | 4           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008488723 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.631      |
# |    explained_variance   | 0.235       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.9        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0221     |
# |    value_loss           | 55          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 493         |
# |    iterations           | 5           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.005541297 |
# |    clip_fraction        | 0.0464      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.606      |
# |    explained_variance   | 0.32        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.5        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0132     |
# |    value_loss           | 62.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 483         |
# |    iterations           | 6           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.005878409 |
# |    clip_fraction        | 0.0576      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.593      |
# |    explained_variance   | 0.5         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.8        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.013      |
# |    value_loss           | 56.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 475         |
# |    iterations           | 7           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008319763 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.59       |
# |    explained_variance   | 0.721       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.11        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0158     |
# |    value_loss           | 43.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 472         |
# |    iterations           | 8           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.004374462 |
# |    clip_fraction        | 0.0534      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.571      |
# |    explained_variance   | 0.676       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.16        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 43.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 9           |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.007217946 |
# |    clip_fraction        | 0.0717      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.563      |
# |    explained_variance   | 0.468       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.71        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00875    |
# |    value_loss           | 38.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 465          |
# |    iterations           | 10           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0053701233 |
# |    clip_fraction        | 0.0328       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.547       |
# |    explained_variance   | 0.264        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.86         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00464     |
# |    value_loss           | 26.7         |
# ------------------------------------------

# %% [markdown]
# ## Save and reload model

# %%
PPO_PATH=os.path.join('Training','Saved Models','PPO_Model_CartPole')

# %%
model.save(PPO_PATH)                                                       #saving the model into PC

# %%
del model                                                                 #DEL model in this notebook

# %%
PPO_PATH
# Out:
# 'Training\\Saved Models\\PPO_Model_CartPole'

# %%
model=PPO.load(PPO_PATH,env=env)                                          #loading model form PC

# %% [markdown]
# ## Evaluation

# %%
evaluate_policy (model,env,n_eval_episodes=10,render=True)
# Out:
# C:\Users\hrith\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (200.0, 0.0)

# %% [raw]
# will return (a,b) , where a=average reward , b=standard deviation in reward

# %%
env.close()            #to close the environment

# %% [markdown]
# ## Test model

# %%
episodes = 5                                                        #loop in 5 times
for episode in range(1, episodes+1):
    obs = env.reset()                                               #reset the evironment to initial conditins
    done = False                                                    #setting variables
    score = 0 
    
    while not done:
        env.render()                                         #view the graphical representation of environment 
        action,_ = model.predict(obs)                        #now using model here, get two outputs 1.model action, 2.next state
        obs, reward, done, info = env.step(action)           #passing action to environment 
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:[200.]
# Episode:2 Score:[200.]
# Episode:3 Score:[200.]
# Episode:4 Score:[200.]
# Episode:5 Score:[200.]

# %%
model.predict(obs)    #return 2 values
# Out:
# (array([0], dtype=int64), None)

# %% [markdown]
# ## Viewing logs in tenserboard

# %%
training_log_path=os.path.join(log_path,'PPO_20')

# %%
training_log_path
# Out:
# 'Training\\Logs\\PPO_20'

# %%
# !tensorboard --logdir={training_log_path}

# %% [markdown]
# ## Adding callback to the training stage

# %%
from stable_baselines3.common.callbacks import EvalCallback , StopTrainingOnRewardThreshold
#EvalCallBack is the callback that runs during the training state
#StopTrainingOnRewardThreshold = to set the training threshold

# %%
save_path=os.path.join('Training','Saved Models')           #To save the best moddels

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=200,verbose=1)

# %%
eval_callback=EvalCallback(env,callback_on_new_best=stop_callback,eval_freq=1000,best_model_save_path=save_path,verbose=1)
#basically we have set the reward_threshold which will be checked at frequency of 1000 and if our model has surprassed 
# the reward threhsold we will save the model on save_path

# %%
model=PPO('MlpPolicy',env,verbose=1,tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000,callback=eval_callback)
# Out:
# Logging to Training\Logs\PPO_2
# C:\Users\hrith\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=1000, episode_reward=74.80 +/- 26.81
# Episode length: 74.80 +/- 26.81
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 74.8     |
# |    mean_reward     | 74.8     |
# | time/              |          |
# |    total_timesteps | 1000     |
# ---------------------------------
# New best mean reward!
# Eval num_timesteps=2000, episode_reward=113.80 +/- 46.23
# Episode length: 113.80 +/- 46.23
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 114      |
# |    mean_reward     | 114      |
# | time/              |          |
# |    total_timesteps | 2000     |
# ---------------------------------
# New best mean reward!
# -----------------------------
# | time/              |      |
# |    fps             | 508  |
# |    iterations      | 1    |
# |    time_elapsed    | 4    |
# |    total_timesteps | 2048 |
# -----------------------------
# Eval num_timesteps=3000, episode_reward=193.40 +/- 9.07
# Episode length: 193.40 +/- 9.07
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 193         |
# |    mean_reward          | 193         |
# | time/                   |             |
# |    total_timesteps      | 3000        |
# | train/                  |             |
# |    approx_kl            | 0.008176746 |
# |    clip_fraction        | 0.096       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.000643    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.7        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0164     |
# |    value_loss           | 60.2        |
# -----------------------------------------
# New best mean reward!
# Eval num_timesteps=4000, episode_reward=172.40 +/- 24.20
# Episode length: 172.40 +/- 24.20
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 172      |
# |    mean_reward     | 172      |
# | time/              |          |
# |    total_timesteps | 4000     |
# ---------------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 365  |
# |    iterations      | 2    |
# |    time_elapsed    | 11   |
# |    total_timesteps | 4096 |
# -----------------------------
# Eval num_timesteps=5000, episode_reward=188.00 +/- 24.00
# Episode length: 188.00 +/- 24.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 188         |
# |    mean_reward          | 188         |
# | time/                   |             |
# |    total_timesteps      | 5000        |
# | train/                  |             |
# |    approx_kl            | 0.010372731 |
# |    clip_fraction        | 0.0797      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.662      |
# |    explained_variance   | 0.099       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.54        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0216     |
# |    value_loss           | 37.9        |
# -----------------------------------------
# Eval num_timesteps=6000, episode_reward=182.40 +/- 26.36
# Episode length: 182.40 +/- 26.36
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 182      |
# |    mean_reward     | 182      |
# | time/              |          |
# |    total_timesteps | 6000     |
# ---------------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 334  |
# |    iterations      | 3    |
# |    time_elapsed    | 18   |
# |    total_timesteps | 6144 |
# -----------------------------
# Eval num_timesteps=7000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 7000        |
# | train/                  |             |
# |    approx_kl            | 0.010089243 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.626      |
# |    explained_variance   | 0.238       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.3        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0208     |
# |    value_loss           | 57.5        |
# -----------------------------------------
# New best mean reward!
# Stopping training because the mean reward 200.00  is above the threshold 200

# %% [markdown]
# ## Changing policy

# %%
net_arch=[dict(pi=[128, 128, 128, 128], vf=[128, 128, 128, 128])]  #new NN arch

# %%
model = PPO('MlpPolicy', env, verbose = 1, policy_kwargs={'net_arch': net_arch})
# Out:
# Using cpu device
# C:\Users\hrith\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\common\policies.py:457: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(

# %%
 model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Eval num_timesteps=1000, episode_reward=9.00 +/- 0.89
# Episode length: 9.00 +/- 0.89
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 9        |
# |    mean_reward     | 9        |
# | time/              |          |
# |    total_timesteps | 1000     |
# ---------------------------------
# C:\Users\hrith\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=2000, episode_reward=9.20 +/- 0.75
# Episode length: 9.20 +/- 0.75
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 9.2      |
# |    mean_reward     | 9.2      |
# | time/              |          |
# |    total_timesteps | 2000     |
# ---------------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 557  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# Eval num_timesteps=3000, episode_reward=76.20 +/- 18.00
# Episode length: 76.20 +/- 18.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 76.2       |
# |    mean_reward          | 76.2       |
# | time/                   |            |
# |    total_timesteps      | 3000       |
# | train/                  |            |
# |    approx_kl            | 0.01374372 |
# |    clip_fraction        | 0.183      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.682     |
# |    explained_variance   | -0.000885  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.06       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0205    |
# |    value_loss           | 19         |
# ----------------------------------------
# Eval num_timesteps=4000, episode_reward=93.20 +/- 53.84
# Episode length: 93.20 +/- 53.84
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 93.2     |
# |    mean_reward     | 93.2     |
# | time/              |          |
# |    total_timesteps | 4000     |
# ---------------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 327  |
# |    iterations      | 2    |
# |    time_elapsed    | 12   |
# |    total_timesteps | 4096 |
# -----------------------------
# Eval num_timesteps=5000, episode_reward=176.20 +/- 25.27
# Episode length: 176.20 +/- 25.27
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 176         |
# |    mean_reward          | 176         |
# | time/                   |             |
# |    total_timesteps      | 5000        |
# | train/                  |             |
# |    approx_kl            | 0.013124826 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.647      |
# |    explained_variance   | 0.363       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.8        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0308     |
# |    value_loss           | 28.9        |
# -----------------------------------------
# Eval num_timesteps=6000, episode_reward=121.60 +/- 4.03
# Episode length: 121.60 +/- 4.03
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 122      |
# |    mean_reward     | 122      |
# | time/              |          |
# |    total_timesteps | 6000     |
# ---------------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 283  |
# |    iterations      | 3    |
# |    time_elapsed    | 21   |
# |    total_timesteps | 6144 |
# -----------------------------
# Eval num_timesteps=7000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 7000        |
# | train/                  |             |
# |    approx_kl            | 0.012248143 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.609      |
# |    explained_variance   | 0.445       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.1        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0319     |
# |    value_loss           | 47.3        |
# -----------------------------------------
# Eval num_timesteps=8000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 200      |
# |    mean_reward     | 200      |
# | time/              |          |
# |    total_timesteps | 8000     |
# ---------------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 264  |
# |    iterations      | 4    |
# |    time_elapsed    | 30   |
# |    total_timesteps | 8192 |
# -----------------------------
# Eval num_timesteps=9000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 9000        |
# | train/                  |             |
# |    approx_kl            | 0.020262245 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.587      |
# |    explained_variance   | 0.568       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.32        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0228     |
# |    value_loss           | 33.6        |
# -----------------------------------------
# Eval num_timesteps=10000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 200      |
# |    mean_reward     | 200      |
# | time/              |          |
# |    total_timesteps | 10000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 250   |
# |    iterations      | 5     |
# |    time_elapsed    | 40    |
# |    total_timesteps | 10240 |
# ------------------------------
# Eval num_timesteps=11000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 200          |
# |    mean_reward          | 200          |
# | time/                   |              |
# |    total_timesteps      | 11000        |
# | train/                  |              |
# |    approx_kl            | 0.0068629757 |
# |    clip_fraction        | 0.0694       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.558       |
# |    explained_variance   | 0.793        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.23         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00618     |
# |    value_loss           | 16.4         |
# ------------------------------------------
# Eval num_timesteps=12000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 200      |
# |    mean_reward     | 200      |
# | time/              |          |
# |    total_timesteps | 12000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 239   |
# |    iterations      | 6     |
# |    time_elapsed    | 51    |
# |    total_timesteps | 12288 |
# ------------------------------
# Eval num_timesteps=13000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 13000       |
# | train/                  |             |
# |    approx_kl            | 0.008325599 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.551      |
# |    explained_variance   | 0.9         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1           |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 13          |
# -----------------------------------------
# Eval num_timesteps=14000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 200      |
# |    mean_reward     | 200      |
# | time/              |          |
# |    total_timesteps | 14000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 237   |
# |    iterations      | 7     |
# |    time_elapsed    | 60    |
# |    total_timesteps | 14336 |
# ------------------------------
# Eval num_timesteps=15000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 15000       |
# | train/                  |             |
# |    approx_kl            | 0.008249769 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.535      |
# |    explained_variance   | 0.724       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.26        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00521    |
# |    value_loss           | 8.14        |
# -----------------------------------------
# Eval num_timesteps=16000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 200      |
# |    mean_reward     | 200      |
# | time/              |          |
# |    total_timesteps | 16000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 237   |
# |    iterations      | 8     |
# |    time_elapsed    | 69    |
# |    total_timesteps | 16384 |
# ------------------------------
# Eval num_timesteps=17000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 17000       |
# | train/                  |             |
# |    approx_kl            | 0.013811495 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.477      |
# |    explained_variance   | 0.644       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.351       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00658    |
# |    value_loss           | 3.91        |
# -----------------------------------------
# Eval num_timesteps=18000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 200      |
# |    mean_reward     | 200      |
# | time/              |          |
# |    total_timesteps | 18000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 237   |
# |    iterations      | 9     |
# |    time_elapsed    | 77    |
# |    total_timesteps | 18432 |
# ------------------------------
# Eval num_timesteps=19000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 200          |
# |    mean_reward          | 200          |
# | time/                   |              |
# |    total_timesteps      | 19000        |
# | train/                  |              |
# |    approx_kl            | 0.0052807173 |
# |    clip_fraction        | 0.101        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.488       |
# |    explained_variance   | 0.227        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.51         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00465     |
# |    value_loss           | 2.84         |
# ------------------------------------------
# Eval num_timesteps=20000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 200      |
# |    mean_reward     | 200      |
# | time/              |          |
# |    total_timesteps | 20000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 237   |
# |    iterations      | 10    |
# |    time_elapsed    | 86    |
# |    total_timesteps | 20480 |
# ------------------------------

# %% [markdown]
# ## Using alternate algorithm

# %%
#Using DQN instead of PPO

# %%
from stable_baselines3 import DQN

# %%
model = DQN('MlpPolicy', env, verbose = 1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training\Logs\DQN_1
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 2529     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 60       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.933    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 3487     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 141      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 3939     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 237      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.847    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 4186     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 322      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.817    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 4143     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 386      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.783    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 4057     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 456      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.753    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 3858     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 519      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.706    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 3662     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 619      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.661    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 3638     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 713      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.628    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 3626     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 783      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.575    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 3628     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 895      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.541    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 3629     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 966      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.45     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 3757     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1158     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.399    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 3849     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1266     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.36     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 3890     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1347     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.321    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 3917     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1430     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.285    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 3963     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1505     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.248    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 4008     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1583     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.216    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 4040     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1651     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.186    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 4048     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1713     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.133    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 4101     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1825     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0932   |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 4143     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1909     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0505   |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 4155     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1999     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 4206     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2103     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 4240     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2186     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 4241     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2261     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 4265     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2348     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 4283     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2436     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 4314     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2523     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 4311     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2579     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 4348     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2687     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 4360     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2759     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 4407     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2878     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 4431     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2978     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 4278     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3032     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 4298     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3122     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 4317     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3210     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 4320     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3332     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 4340     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3449     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 4358     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3544     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 4287     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3634     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 4270     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3712     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 4262     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3782     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 4287     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3876     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 4280     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3932     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 4283     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3997     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 4295     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4087     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 4305     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4209     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 4318     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4309     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 4334     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4404     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 4319     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4495     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 4309     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4553     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 4302     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4695     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 4241     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4772     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 4222     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4844     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 4195     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4914     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 4210     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5047     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 4211     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5121     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 4238     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5230     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 4242     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5287     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 4226     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5391     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 4190     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5507     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 4154     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5593     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 4134     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5688     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 4125     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5781     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 4144     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5877     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 4154     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5945     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 4171     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6022     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 4184     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6116     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 4204     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6230     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 4208     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6324     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 4232     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6468     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 4264     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6633     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 4261     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6718     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 4272     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6804     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 4284     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6901     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 4313     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7034     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 4322     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7111     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 4332     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7193     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 4341     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7270     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 4354     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7367     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 4359     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7438     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 4369     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7522     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 4381     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7594     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 4382     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7648     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 4403     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7771     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 4412     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7859     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 4416     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7946     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 4420     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8005     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 4422     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8076     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 4426     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8138     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 4432     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8219     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 4458     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8397     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 4468     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8497     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 4490     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8654     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 4497     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8770     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 4480     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8835     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 4481     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8923     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 4467     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9014     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 4376     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9107     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 4356     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9210     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 4369     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9346     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 4370     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9426     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 4369     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9505     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 4350     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9558     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 4350     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9616     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 4361     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9715     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 4366     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9783     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 4376     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9888     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 4380     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 9990     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 4351     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10042    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 4363     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10157    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 4366     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10263    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 4367     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10317    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 4376     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10402    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 4386     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10502    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 4397     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10612    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 4401     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10672    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 4411     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10790    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 4416     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10858    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 4425     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 10968    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 4429     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11027    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 4435     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11109    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 4436     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11200    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 4443     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11289    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 4451     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11375    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 4462     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11523    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 4462     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11608    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 4467     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11711    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 4473     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11822    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 4477     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11905    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 4483     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11986    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 4483     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12058    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 4485     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12119    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 4485     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12228    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 4481     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12296    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 4483     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12375    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 4491     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12487    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 4490     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12549    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 4499     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12660    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 4507     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12753    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 4509     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12824    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 4516     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12920    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 4518     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12993    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 4521     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13074    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 4472     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13152    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 4462     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13215    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 4465     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13332    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 4456     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 13443    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 4457     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 13517    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 4462     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 13594    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 4467     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 13677    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# ...
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 696      |
# |    fps              | 4518     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 15785    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 700      |
# |    fps              | 4520     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 15868    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 704      |
# |    fps              | 4522     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 15935    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 708      |
# |    fps              | 4527     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 16020    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 712      |
# |    fps              | 4527     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 16075    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 716      |
# |    fps              | 4528     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 16162    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 720      |
# |    fps              | 4532     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 16289    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 724      |
# |    fps              | 4532     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 16378    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 728      |
# |    fps              | 4535     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 16459    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 732      |
# |    fps              | 4533     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 16507    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 736      |
# |    fps              | 4535     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 16563    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 740      |
# |    fps              | 4540     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 16719    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 744      |
# |    fps              | 4535     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 16821    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 748      |
# |    fps              | 4542     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 16932    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 752      |
# |    fps              | 4545     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 17035    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 756      |
# |    fps              | 4551     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 17119    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 760      |
# |    fps              | 4555     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 17205    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 764      |
# |    fps              | 4556     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 17296    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 768      |
# |    fps              | 4558     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 17378    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 772      |
# |    fps              | 4563     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 17507    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 776      |
# |    fps              | 4564     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 17586    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 780      |
# |    fps              | 4567     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 17677    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 784      |
# |    fps              | 4563     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 17741    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 788      |
# |    fps              | 4559     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 17807    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 792      |
# |    fps              | 4562     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 17907    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 796      |
# |    fps              | 4563     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 17962    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 800      |
# |    fps              | 4562     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 18040    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 804      |
# |    fps              | 4565     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 18131    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 808      |
# |    fps              | 4566     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 18201    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 812      |
# |    fps              | 4567     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 18273    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 816      |
# |    fps              | 4569     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 18339    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 820      |
# |    fps              | 4569     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 18420    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 824      |
# |    fps              | 4572     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 18492    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 828      |
# |    fps              | 4575     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 18552    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 832      |
# |    fps              | 4577     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 18624    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 836      |
# |    fps              | 4577     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 18696    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 840      |
# |    fps              | 4578     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 18780    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 844      |
# |    fps              | 4579     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 18873    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 848      |
# |    fps              | 4586     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19007    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 852      |
# |    fps              | 4588     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19077    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 856      |
# |    fps              | 4591     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19145    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 860      |
# |    fps              | 4592     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19232    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 864      |
# |    fps              | 4594     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19300    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 868      |
# |    fps              | 4591     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19367    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 872      |
# |    fps              | 4590     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19435    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 876      |
# |    fps              | 4592     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19535    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 880      |
# |    fps              | 4594     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19636    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 884      |
# |    fps              | 4596     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19719    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 888      |
# |    fps              | 4596     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19779    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 892      |
# |    fps              | 4595     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19862    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 896      |
# |    fps              | 4597     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19949    |
# ----------------------------------
